# %%
# !ngrok config add-authtoken add your token here  # to do
# Out:
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml

# %%
# Lancement Streamlit + tunnel public
from pyngrok import ngrok
import subprocess
import time

# Tue les anciens tunnels
# !pkill streamlit
# !pkill ngrok

# Démarre Streamlit en arrière-plan
process = subprocess.Popen(['streamlit', 'run', 'app.py', '--server.port', '8501'])

# Tunnel ngrok
public_url = ngrok.connect(8501)
print(f"\n TON APP EST PRÊTE ! → {public_url} \n")
print("Clique sur le lien ci-dessus")

# Garde la cellule vivante
time.sleep(999999)
